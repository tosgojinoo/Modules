# %% [markdown]
# # pairplot

# %%
sns.pairplot(df_sampled, diag_kind = 'kde')
plt.show()

# %% [markdown]
# # subplots

# %%
f, axes = plt.subplots(nrows=2,ncols=8, figsize=(100, 20), sharex=True)

for i in range(8):
    col = group_tot_top8.columns[i+1]
    sns.barplot(x="month", y=col, data=group_tot_top8[['month', f'{col}']], ax=axes[0][i], palette="rocket").set_title(f'{col} trend', fontsize=25)
    axes[0][i].set_xlabel('월', fontsize=25)
    axes[0][i].set_ylabel('판매량', fontsize=25)
    
for ax in f.axes:
    plt.sca(ax)
    plt.tick_params(axis='both', which='major', labelsize=25)

# %% [markdown]
# # End
